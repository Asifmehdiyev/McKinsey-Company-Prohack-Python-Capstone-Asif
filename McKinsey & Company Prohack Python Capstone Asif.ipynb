# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msn

from sklearn.preprocessing import RobustScaler # preprocessing

from sklearn import linear_model
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

from sklearn.model_selection import train_test_split 
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error,mean_absolute_percentage_error
from sklearn import base
from sklearn.model_selection import KFold

from warnings import filterwarnings
from scipy.stats import zscore
from IPython.display import Image
import pickle
# %matplotlib inline

# %%
sns.set(style = 'darkgrid', palette = 'bright')
pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (20, 15)
plt.style.use('ggplot')
filterwarnings(action = 'ignore')

# %% [markdown]
# ## For displaying all column names

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %% [markdown]
# ## Exploratory Data Analysis process for both datasets

# %%
df_train.head()
# Out:
#    galactic year                        galaxy  existence expectancy index  \
# 0         990025  Large Magellanic Cloud (LMC)                    0.628657
# 1         990025              Camelopardalis B                    0.818082
# 2         990025                       Virgo I                    0.659443
# 3         990025            UGC 8651 (DDO 181)                    0.555862
# 4         990025                  Tucana Dwarf                    0.991196
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      63.125200             27109.234310      0.646039
# 1                      81.004994             30166.793958      0.852246
# 2                      59.570534              8441.707353      0.499762
# 3                      52.333293                      NaN           NaN
# 4                      81.802464             81033.956906      1.131163
#
#    Expected years of education (galactic years)  \
# 0                                      8.240543
# 1                                     10.671823
# 2                                      8.840316
# 3                                           NaN
# 4                                     13.800672
#
#    Mean years of education (galactic years)  \
# 0                                       NaN
# 1                                  4.742470
# 2                                  5.583973
# 3                                       NaN
# 4                                 13.188907
#
#    Intergalactic Development Index (IDI)  Education Index  \
# 0                                    NaN              NaN
# 1                               0.833624         0.467873
# 2                               0.469110         0.363837
# 3                                    NaN              NaN
# 4                               0.910341         0.918353
#
#    Intergalactic Development Index (IDI), Rank  \
# 0                                          NaN
# 1                                   152.522198
# 2                                   209.813266
# 3                                          NaN
# 4                                    71.885345
#
#    Population using at least basic drinking-water services (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population using at least basic sanitation services (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Gross capital formation (% of GGP)  Population, total (millions)  \
# 0                           38.305483                    681.841086
# 1                           36.255559                    423.973089
# 2                           18.093991                    285.572207
# 3                                 NaN                    327.202247
# 4                           34.497468                    633.799718
#
#    Population, urban (%)  Mortality rate, under-five (per 1,000 live births)  \
# 0              22.131436                                         150.259290
# 1              89.294181                                         117.069332
# 2              57.491083                                         226.523760
# 3              47.785456                                         279.000175
# 4             103.562629                                          28.359587
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                      129.841789
# 1                                       61.822590
# 2                                      134.558437
# 3                                      193.228799
# 4                                       51.098250
#
#    Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))  \
# 0                                          12.403812
# 1                                          13.054898
# 2                                          15.963001
# 3                                          12.940991
# 4                                          25.521926
#
#    Population, ages 15–64 (millions)  \
# 0                         490.446400
# 1                         560.547706
# 2                         555.012461
# 3                         766.807703
# 4                         585.434804
#
#    Population, ages 65 and older (millions)  \
# 0                                 60.121580
# 1                                 58.573002
# 2                                 43.078497
# 3                                 51.318372
# 4                                 56.158054
#
#    Life expectancy at birth, male (galactic years)  \
# 0                                        57.028183
# 1                                        69.873905
# 2                                        59.462626
# 3                                        50.535797
# 4                                        85.020965
#
#    Life expectancy at birth, female (galactic years)  \
# 0                                          69.825369
# 1                                          76.752305
# 2                                          59.152506
# 3                                          54.931369
# 4                                          84.708158
#
#    Population, under age 5 (millions)  \
# 0                           46.018230
# 1                           40.167960
# 2                           91.093668
# 3                           92.727892
# 4                           71.493810
#
#    Young age (0-14) dependency ratio (per 100 creatures ages 15-64)  \
# 0                                          98.216072
# 1                                          88.322574
# 2                                         114.163995
# 3                                          97.645232
# 4                                          53.835875
#
#    Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                         174.617899
# 1                                         109.892385
# 2                                         230.573666
# 3                                         198.971328
# 4                                          61.008654
#
#    Total unemployment rate (female to male ratio)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Vulnerable employment (% of total employment)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Unemployment, total (% of labour force)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Employment in agriculture (% of total employment)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Labour force participation rate (% ages 15 and older)  \
# 0                                          79.614066
# 1                                          63.813720
# 2                                          80.874149
# 3                                          84.721882
# 4                                          61.086141
#
#    Labour force participation rate (% ages 15 and older), female  \
# 0                                          73.071600
# 1                                          45.482071
# 2                                          75.217727
# 3                                          82.026125
# 4                                          66.286848
#
#    Employment in services (% of total employment)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Labour force participation rate (% ages 15 and older), male  \
# 0                                          85.851544
# 1                                          93.526359
# 2                                          95.041272
# 3                                          86.307832
# 4                                          76.671844
#
#    Employment to population ratio (% ages 15 and older)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Jungle area (% of total land area)  \
# 0                           73.166354
# 1                           35.590371
# 2                           48.892555
# 3                                 NaN
# 4                                 NaN
#
#    Share of employment in nonagriculture, female (% of total employment in nonagriculture)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Youth unemployment rate (female to male ratio)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Unemployment, youth (% ages 15–24)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Mortality rate, female grown up (per 1,000 people)  \
# 0                                         431.270303
# 1                                         221.411013
# 2                                         513.730396
# 3                                         497.785386
# 4                                         150.173225
#
#    Mortality rate, male grown up (per 1,000 people)  \
# 0                                        466.089287
# 1                                        376.475151
# 2                                        581.063598
# 3                                        612.106994
# 4                                        213.691418
#
#    Infants lacking immunization, red hot disease (% of one-galactic year-olds)  \
# 0                                          16.167871
# 1                                          36.639519
# 2                                          31.958515
# 3                                                NaN
# 4                                          29.577375
#
#    Infants lacking immunization, Combination Vaccine (% of one-galactic year-olds)  \
# 0                                           8.223563
# 1                                          21.007339
# 2                                          18.954434
# 3                                                NaN
# 4                                          11.134867
#
#    Gross galactic product (GGP) per capita  \
# 0                             21158.324865
# 1                             24984.044391
# 2                             19860.121520
# 3                                      NaN
# 4                             75156.049406
#
#    Gross galactic product (GGP), total  \
# 0                          7760.639489
# 1                          6969.137436
# 2                          3276.634176
# 3                                  NaN
# 4                          8957.403969
#
#    Outer Galaxies direct investment, net inflows (% of GGP)  \
# 0                                          13.617993
# 1                                          19.484830
# 2                                          13.357158
# 3                                                NaN
# 4                                                NaN
#
#    Exports and imports (% of GGP)  \
# 0                       94.859306
# 1                       77.935108
# 2                       87.508620
# 3                             NaN
# 4                      241.901357
#
#    Share of seats in senate (% held by female)  Natural resource depletion  \
# 0                                          NaN                    8.436392
# 1                                          NaN                   12.549351
# 2                                          NaN                   13.949733
# 3                                          NaN                         NaN
# 4                                          NaN                   15.090820
#
#    Mean years of education, female (galactic years)  \
# 0                                               NaN
# 1                                          7.096070
# 2                                          6.494764
# 3                                               NaN
# 4                                         11.830216
#
#    Mean years of education, male (galactic years)  \
# 0                                             NaN
# 1                                        8.098794
# 2                                        6.730145
# 3                                             NaN
# 4                                       12.122982
#
#    Expected years of education, female (galactic years)  \
# 0                                                NaN
# 1                                          11.797213
# 2                                           6.960041
# 3                                                NaN
# 4                                                NaN
#
#    Expected years of education, male (galactic years)  \
# 0                                                NaN
# 1                                          13.477707
# 2                                           6.805405
# 3                                                NaN
# 4                                                NaN
#
#    Maternal mortality ratio (deaths per 100,000 live births)  \
# 0                                        1237.228737
# 1                                         544.458925
# 2                                        1537.953483
# 3                                        2016.655551
# 4                                         232.573140
#
#    Renewable energy consumption (% of total final energy consumption)  \
# 0                                         118.434634
# 1                                          53.753525
# 2                                         126.063691
# 3                                                NaN
# 4                                          39.192277
#
#    Estimated gross galactic income per capita, male  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Estimated gross galactic income per capita, female  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rural population with access to electricity (%)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                       134.967049
#
#    Domestic credit provided by financial sector (% of GGP)  \
# 0                                          75.604799
# 1                                          57.214150
# 2                                          76.141735
# 3                                                NaN
# 4                                                NaN
#
#    Population with at least some secondary education, female (% ages 25 and older)  \
# 0                                                NaN
# 1                                          57.314932
# 2                                          42.405827
# 3                                                NaN
# 4                                          77.223935
#
#    Population with at least some secondary education, male (% ages 25 and older)  \
# 0                                                NaN
# 1                                          56.187355
# 2                                          53.927715
# 3                                                NaN
# 4                                          75.475076
#
#    Gross fixed capital formation (% of GGP)  Remittances, inflows (% of GGP)  \
# 0                                 42.616284                              NaN
# 1                                 29.908422                         6.225946
# 2                                 18.732049                         4.138115
# 3                                       NaN                              NaN
# 4                                 31.398393                              NaN
#
#    Population with at least some secondary education (% ages 25 and older)  \
# 0                                                NaN
# 1                                          44.780023
# 2                                          24.030945
# 3                                                NaN
# 4                                          66.674651
#
#    Intergalactic inbound tourists (thousands)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Gross enrolment ratio, primary (% of primary under-age population)  \
# 0                                                NaN
# 1                                         120.886080
# 2                                          96.626831
# 3                                                NaN
# 4                                                NaN
#
#    Respiratory disease incidence (per 100,000 people)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Interstellar phone subscriptions (per 100 people)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Interstellar Data Net users, total (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Current health expenditure (% of GGP)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Intergalactic Development Index (IDI), female  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Intergalactic Development Index (IDI), male  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Gender Development Index (GDI)  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#    Intergalactic Development Index (IDI), female, Rank  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Intergalactic Development Index (IDI), male, Rank  Adjusted net savings   \
# 0                                                NaN                    NaN
# 1                                                NaN              19.177926
# 2                                                NaN              21.151265
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#    Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total  \
# 0                                                NaN
# 1                                                NaN
# 2                                           6.534020
# 3                                           5.912194
# 4                                           5.611753
#
#    Private galaxy capital flows (% of GGP)  Gender Inequality Index (GII)  \
# 0                                      NaN                            NaN
# 1                                22.785018                            NaN
# 2                                      NaN                            NaN
# 3                                      NaN                            NaN
# 4                                      NaN                            NaN
#
#           y
# 0  0.052590
# 1  0.059868
# 2  0.050449
# 3  0.049394
# 4  0.154247

# %%
df_test.head()
# Out:
#    galactic year         galaxy  existence expectancy index  \
# 0        1007012        KK98 77                    0.456086
# 1        1007012  Reticulum III                    0.529835
# 2        1008016  Reticulum III                    0.560976
# 3        1007012        Segue 1                    0.565910
# 4        1013042        Virgo I                    0.588274
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      51.562543             12236.576447      0.593325
# 1                      57.228262              3431.883825      0.675407
# 2                      59.379539             27562.914252      0.594624
# 3                      59.952390             20352.232905      0.837700
# 4                      55.428320             23959.704016      0.520579
#
#    Expected years of education (galactic years)  \
# 0                                     10.414164
# 1                                      7.239485
# 2                                     11.774890
# 3                                     11.613621
# 4                                     10.392416
#
#    Mean years of education (galactic years)  \
# 0                                 10.699072
# 1                                  5.311122
# 2                                  5.937797
# 3                                 10.067882
# 4                                  6.374637
#
#    Intergalactic Development Index (IDI)  Education Index  \
# 0                               0.547114         0.556267
# 1                               0.497688         0.409969
# 2                               0.544744         0.486167
# 3                               0.691641         0.523441
# 4                               0.530676         0.580418
#
#    Intergalactic Development Index (IDI), Rank  \
# 0                                   232.621842
# 1                                   247.580771
# 2                                   249.798771
# 3                                   211.505060
# 4                                   234.721069
#
#    Population using at least basic drinking-water services (%)  \
# 0                                         105.193088
# 1                                          55.730638
# 2                                          58.755900
# 3                                          70.176431
# 4                                          69.768692
#
#    Population using at least basic sanitation services (%)  \
# 0                                          64.241392
# 1                                          46.217440
# 2                                          48.897493
# 3                                          61.254104
# 4                                          51.316940
#
#    Gross capital formation (% of GGP)  Population, total (millions)  \
# 0                           17.418350                           NaN
# 1                           33.027886                           NaN
# 2                           31.613362                           NaN
# 3                           34.399007                           NaN
# 4                           15.657091                   1106.554194
#
#    Population, urban (%)  Mortality rate, under-five (per 1,000 live births)  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4              64.382217                                         219.588961
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                      129.974418
#
#    Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          14.013421
#
#    Population, ages 15–64 (millions)  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                         474.877713
#
#    Population, ages 65 and older (millions)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                 21.305665
#
#    Life expectancy at birth, male (galactic years)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                        59.144562
#
#    Life expectancy at birth, female (galactic years)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          63.990109
#
#    Population, under age 5 (millions)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                           80.409057
#
#    Young age (0-14) dependency ratio (per 100 creatures ages 15-64)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         111.084652
#
#    Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         162.451451
#
#    Total unemployment rate (female to male ratio)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                        2.421466
#
#    Vulnerable employment (% of total employment)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                     126.050516
#
#    Unemployment, total (% of labour force)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                13.370766
#
#    Employment in agriculture (% of total employment)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          89.542879
#
#    Labour force participation rate (% ages 15 and older)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          83.677526
#
#    Labour force participation rate (% ages 15 and older), female  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           87.84634
#
#    Employment in services (% of total employment)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                       28.815475
#
#    Labour force participation rate (% ages 15 and older), male  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          88.782958
#
#    Employment to population ratio (% ages 15 and older)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           76.50274
#
#    Jungle area (% of total land area)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                           56.338491
#
#    Share of employment in nonagriculture, female (% of total employment in nonagriculture)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          45.923296
#
#    Youth unemployment rate (female to male ratio)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                        2.043633
#
#    Unemployment, youth (% ages 15–24)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                           23.401352
#
#    Mortality rate, female grown up (per 1,000 people)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         546.437704
#
#    Mortality rate, male grown up (per 1,000 people)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                        552.698573
#
#    Infants lacking immunization, red hot disease (% of one-galactic year-olds)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          92.815852
#
#    Infants lacking immunization, Combination Vaccine (% of one-galactic year-olds)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          76.093251
#
#    Gross galactic product (GGP) per capita  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                             28890.168075
#
#    Gross galactic product (GGP), total  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                          5995.978901
#
#    Outer Galaxies direct investment, net inflows (% of GGP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           8.248885
#
#    Exports and imports (% of GGP)  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                       87.376942
#
#    Share of seats in senate (% held by female)  Natural resource depletion  \
# 0                                          NaN                         NaN
# 1                                          NaN                         NaN
# 2                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                    8.776004
#
#    Mean years of education, female (galactic years)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                          5.628603
#
#    Mean years of education, male (galactic years)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                        7.518383
#
#    Expected years of education, female (galactic years)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           8.975221
#
#    Expected years of education, male (galactic years)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           8.919711
#
#    Maternal mortality ratio (deaths per 100,000 live births)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                        1034.065346
#
#    Renewable energy consumption (% of total final energy consumption)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          96.028122
#
#    Estimated gross galactic income per capita, male  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                       21309.50697
#
#    Estimated gross galactic income per capita, female  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                       18103.974021
#
#    Rural population with access to electricity (%)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                        50.233592
#
#    Domestic credit provided by financial sector (% of GGP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          86.296925
#
#    Population with at least some secondary education, female (% ages 25 and older)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          29.065459
#
#    Population with at least some secondary education, male (% ages 25 and older)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          58.562225
#
#    Gross fixed capital formation (% of GGP)  Remittances, inflows (% of GGP)  \
# 0                                       NaN                              NaN
# 1                                       NaN                              NaN
# 2                                       NaN                              NaN
# 3                                       NaN                              NaN
# 4                                 13.313253                              NaN
#
#    Population with at least some secondary education (% ages 25 and older)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          42.980727
#
#    Intergalactic inbound tourists (thousands)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                 99276.25673
#
#    Gross enrolment ratio, primary (% of primary under-age population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Respiratory disease incidence (per 100,000 people)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         458.186555
#
#    Interstellar phone subscriptions (per 100 people)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          79.177012
#
#    Interstellar Data Net users, total (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          41.585873
#
#    Current health expenditure (% of GGP)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                               7.357729
#
#    Intergalactic Development Index (IDI), female  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                       0.583373
#
#    Intergalactic Development Index (IDI), male  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                     0.600445
#
#    Gender Development Index (GDI)  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                        0.856158
#
#    Intergalactic Development Index (IDI), female, Rank  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         206.674424
#
#    Intergalactic Development Index (IDI), male, Rank  Adjusted net savings   \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                         224.104054                    NaN
#
#    Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           7.687626
#
#    Private galaxy capital flows (% of GGP)  Gender Inequality Index (GII)
# 0                                      NaN                            NaN
# 1                                      NaN                            NaN
# 2                                      NaN                            NaN
# 3                                      NaN                            NaN
# 4                                      NaN                            NaN

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3865 entries, 0 to 3864
# Data columns (total 80 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   galactic year                                                                            3865 non-null   int64
#  1   galaxy                                                                                   3865 non-null   object
#  2   existence expectancy index                                                               3864 non-null   float64
#  3   existence expectancy at birth                                                            3864 non-null   float64
#  4   Gross income per capita                                                                  3837 non-null   float64
#  5   Income Index                                                                             3837 non-null   float64
#  6   Expected years of education (galactic years)                                             3732 non-null   float64
#  7   Mean years of education (galactic years)                                                 3502 non-null   float64
#  8   Intergalactic Development Index (IDI)                                                    3474 non-null   float64
#  9   Education Index                                                                          3474 non-null   float64
#  10  Intergalactic Development Index (IDI), Rank                                              3432 non-null   float64
#  11  Population using at least basic drinking-water services (%)                              2021 non-null   float64
#  12  Population using at least basic sanitation services (%)                                  2015 non-null   float64
#  13  Gross capital formation (% of GGP)                                                       1502 non-null   float64
#  14  Population, total (millions)                                                             1271 non-null   float64
#  15  Population, urban (%)                                                                    1271 non-null   float64
#  16  Mortality rate, under-five (per 1,000 live births)                                       1271 non-null   float64
#  17  Mortality rate, infant (per 1,000 live births)                                           1259 non-null   float64
#  18  Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))         1264 non-null   float64
#  19  Population, ages 15–64 (millions)                                                        1264 non-null   float64
#  20  Population, ages 65 and older (millions)                                                 1264 non-null   float64
#  21  Life expectancy at birth, male (galactic years)                                          1264 non-null   float64
#  22  Life expectancy at birth, female (galactic years)                                        1264 non-null   float64
#  23  Population, under age 5 (millions)                                                       1264 non-null   float64
#  24  Young age (0-14) dependency ratio (per 100 creatures ages 15-64)                         1264 non-null   float64
#  25  Adolescent birth rate (births per 1,000 female creatures ages 15-19)                     1252 non-null   float64
#  26  Total unemployment rate (female to male ratio)                                           1237 non-null   float64
#  27  Vulnerable employment (% of total employment)                                            1237 non-null   float64
#  28  Unemployment, total (% of labour force)                                                  1237 non-null   float64
#  29  Employment in agriculture (% of total employment)                                        1237 non-null   float64
#  30  Labour force participation rate (% ages 15 and older)                                    1237 non-null   float64
#  31  Labour force participation rate (% ages 15 and older), female                            1237 non-null   float64
#  32  Employment in services (% of total employment)                                           1237 non-null   float64
#  33  Labour force participation rate (% ages 15 and older), male                              1237 non-null   float64
#  34  Employment to population ratio (% ages 15 and older)                                     1237 non-null   float64
#  35  Jungle area (% of total land area)                                                       1234 non-null   float64
#  36  Share of employment in nonagriculture, female (% of total employment in nonagriculture)  1237 non-null   float64
#  37  Youth unemployment rate (female to male ratio)                                           1236 non-null   float64
#  38  Unemployment, youth (% ages 15–24)                                                       1236 non-null   float64
#  39  Mortality rate, female grown up (per 1,000 people)                                       1253 non-null   float64
#  40  Mortality rate, male grown up (per 1,000 people)                                         1253 non-null   float64
#  41  Infants lacking immunization, red hot disease (% of one-galactic year-olds)              1219 non-null   float64
#  42  Infants lacking immunization, Combination Vaccine (% of one-galactic year-olds)          1219 non-null   float64
#  43  Gross galactic product (GGP) per capita                                                  1202 non-null   float64
#  44  Gross galactic product (GGP), total                                                      1202 non-null   float64
#  45  Outer Galaxies direct investment, net inflows (% of GGP)                                 1169 non-null   float64
#  46  Exports and imports (% of GGP)                                                           1144 non-null   float64
#  47  Share of seats in senate (% held by female)                                              1123 non-null   float64
#  48  Natural resource depletion                                                               1132 non-null   float64
#  49  Mean years of education, female (galactic years)                                         1140 non-null   float64
#  50  Mean years of education, male (galactic years)                                           1138 non-null   float64
#  51  Expected years of education, female (galactic years)                                     1109 non-null   float64
#  52  Expected years of education, male (galactic years)                                       1108 non-null   float64
#  53  Maternal mortality ratio (deaths per 100,000 live births)                                1252 non-null   float64
#  54  Renewable energy consumption (% of total final energy consumption)                       1235 non-null   float64
#  55  Estimated gross galactic income per capita, male                                         1055 non-null   float64
#  56  Estimated gross galactic income per capita, female                                       1055 non-null   float64
#  57  Rural population with access to electricity (%)                                          1029 non-null   float64
#  58  Domestic credit provided by financial sector (% of GGP)                                  1079 non-null   float64
#  59  Population with at least some secondary education, female (% ages 25 and older)          1089 non-null   float64
#  60  Population with at least some secondary education, male (% ages 25 and older)            1087 non-null   float64
#  61  Gross fixed capital formation (% of GGP)                                                 1074 non-null   float64
#  62  Remittances, inflows (% of GGP)                                                          1028 non-null   float64
#  63  Population with at least some secondary education (% ages 25 and older)                  1051 non-null   float64
#  64  Intergalactic inbound tourists (thousands)                                               995 non-null    float64
#  65  Gross enrolment ratio, primary (% of primary under-age population)                       1038 non-null   float64
#  66  Respiratory disease incidence (per 100,000 people)                                       896 non-null    float64
#  67  Interstellar phone subscriptions (per 100 people)                                        891 non-null    float64
#  68  Interstellar Data Net users, total (% of population)                                     872 non-null    float64
#  69  Current health expenditure (% of GGP)                                                    867 non-null    float64
#  70  Intergalactic Development Index (IDI), female                                            916 non-null    float64
#  71  Intergalactic Development Index (IDI), male                                              915 non-null    float64
#  72  Gender Development Index (GDI)                                                           914 non-null    float64
#  73  Intergalactic Development Index (IDI), female, Rank                                      893 non-null    float64
#  74  Intergalactic Development Index (IDI), male, Rank                                        892 non-null    float64
#  75  Adjusted net savings                                                                     912 non-null    float64
#  76  Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total                941 non-null    float64
#  77  Private galaxy capital flows (% of GGP)                                                  874 non-null    float64
#  78  Gender Inequality Index (GII)                                                            844 non-null    float64
#  79  y                                                                                        3865 non-null   float64
# dtypes: float64(78), int64(1), object(1)
# memory usage: 2.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 890 entries, 0 to 889
# Data columns (total 79 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   galactic year                                                                            890 non-null    int64
#  1   galaxy                                                                                   890 non-null    object
#  2   existence expectancy index                                                               885 non-null    float64
#  3   existence expectancy at birth                                                            885 non-null    float64
#  4   Gross income per capita                                                                  885 non-null    float64
#  5   Income Index                                                                             885 non-null    float64
#  6   Expected years of education (galactic years)                                             885 non-null    float64
#  7   Mean years of education (galactic years)                                                 882 non-null    float64
#  8   Intergalactic Development Index (IDI)                                                    882 non-null    float64
#  9   Education Index                                                                          882 non-null    float64
#  10  Intergalactic Development Index (IDI), Rank                                              880 non-null    float64
#  11  Population using at least basic drinking-water services (%)                              880 non-null    float64
#  12  Population using at least basic sanitation services (%)                                  880 non-null    float64
#  13  Gross capital formation (% of GGP)                                                       828 non-null    float64
#  14  Population, total (millions)                                                             615 non-null    float64
#  15  Population, urban (%)                                                                    615 non-null    float64
#  16  Mortality rate, under-five (per 1,000 live births)                                       615 non-null    float64
#  17  Mortality rate, infant (per 1,000 live births)                                           615 non-null    float64
#  18  Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))         610 non-null    float64
#  19  Population, ages 15–64 (millions)                                                        610 non-null    float64
#  20  Population, ages 65 and older (millions)                                                 610 non-null    float64
#  21  Life expectancy at birth, male (galactic years)                                          610 non-null    float64
#  22  Life expectancy at birth, female (galactic years)                                        610 non-null    float64
#  23  Population, under age 5 (millions)                                                       610 non-null    float64
#  24  Young age (0-14) dependency ratio (per 100 creatures ages 15-64)                         610 non-null    float64
#  25  Adolescent birth rate (births per 1,000 female creatures ages 15-19)                     610 non-null    float64
#  26  Total unemployment rate (female to male ratio)                                           605 non-null    float64
#  27  Vulnerable employment (% of total employment)                                            605 non-null    float64
#  28  Unemployment, total (% of labour force)                                                  605 non-null    float64
#  29  Employment in agriculture (% of total employment)                                        605 non-null    float64
#  30  Labour force participation rate (% ages 15 and older)                                    605 non-null    float64
#  31  Labour force participation rate (% ages 15 and older), female                            605 non-null    float64
#  32  Employment in services (% of total employment)                                           605 non-null    float64
#  33  Labour force participation rate (% ages 15 and older), male                              605 non-null    float64
#  34  Employment to population ratio (% ages 15 and older)                                     605 non-null    float64
#  35  Jungle area (% of total land area)                                                       608 non-null    float64
#  36  Share of employment in nonagriculture, female (% of total employment in nonagriculture)  605 non-null    float64
#  37  Youth unemployment rate (female to male ratio)                                           605 non-null    float64
#  38  Unemployment, youth (% ages 15–24)                                                       605 non-null    float64
#  39  Mortality rate, female grown up (per 1,000 people)                                       595 non-null    float64
#  40  Mortality rate, male grown up (per 1,000 people)                                         595 non-null    float64
#  41  Infants lacking immunization, red hot disease (% of one-galactic year-olds)              615 non-null    float64
#  42  Infants lacking immunization, Combination Vaccine (% of one-galactic year-olds)          615 non-null    float64
#  43  Gross galactic product (GGP) per capita                                                  605 non-null    float64
#  44  Gross galactic product (GGP), total                                                      605 non-null    float64
#  45  Outer Galaxies direct investment, net inflows (% of GGP)                                 610 non-null    float64
#  46  Exports and imports (% of GGP)                                                           589 non-null    float64
#  47  Share of seats in senate (% held by female)                                              600 non-null    float64
#  48  Natural resource depletion                                                               591 non-null    float64
#  49  Mean years of education, female (galactic years)                                         575 non-null    float64
#  50  Mean years of education, male (galactic years)                                           575 non-null    float64
#  51  Expected years of education, female (galactic years)                                     595 non-null    float64
#  52  Expected years of education, male (galactic years)                                       595 non-null    float64
#  53  Maternal mortality ratio (deaths per 100,000 live births)                                530 non-null    float64
#  54  Renewable energy consumption (% of total final energy consumption)                       534 non-null    float64
#  55  Estimated gross galactic income per capita, male                                         605 non-null    float64
#  56  Estimated gross galactic income per capita, female                                       605 non-null    float64
#  57  Rural population with access to electricity (%)                                          615 non-null    float64
#  58  Domestic credit provided by financial sector (% of GGP)                                  569 non-null    float64
#  59  Population with at least some secondary education, female (% ages 25 and older)          550 non-null    float64
#  60  Population with at least some secondary education, male (% ages 25 and older)            550 non-null    float64
#  61  Gross fixed capital formation (% of GGP)                                                 556 non-null    float64
#  62  Remittances, inflows (% of GGP)                                                          576 non-null    float64
#  63  Population with at least some secondary education (% ages 25 and older)                  540 non-null    float64
#  64  Intergalactic inbound tourists (thousands)                                               574 non-null    float64
#  65  Gross enrolment ratio, primary (% of primary under-age population)                       504 non-null    float64
#  66  Respiratory disease incidence (per 100,000 people)                                       615 non-null    float64
#  67  Interstellar phone subscriptions (per 100 people)                                        613 non-null    float64
#  68  Interstellar Data Net users, total (% of population)                                     603 non-null    float64
#  69  Current health expenditure (% of GGP)                                                    606 non-null    float64
#  70  Intergalactic Development Index (IDI), female                                            560 non-null    float64
#  71  Intergalactic Development Index (IDI), male                                              560 non-null    float64
#  72  Gender Development Index (GDI)                                                           560 non-null    float64
#  73  Intergalactic Development Index (IDI), female, Rank                                      549 non-null    float64
#  74  Intergalactic Development Index (IDI), male, Rank                                        549 non-null    float64
#  75  Adjusted net savings                                                                     519 non-null    float64
#  76  Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total                482 non-null    float64
#  77  Private galaxy capital flows (% of GGP)                                                  536 non-null    float64
#  78  Gender Inequality Index (GII)                                                            529 non-null    float64
# dtypes: float64(77), int64(1), object(1)
# memory usage: 549.4+ KB

# %%
df_train.columns
# Out:
# Index(['galactic year', 'galaxy', 'existence expectancy index',
#        'existence expectancy at birth', 'Gross income per capita',
#        'Income Index', 'Expected years of education (galactic years)',
#        'Mean years of education (galactic years)',
#        'Intergalactic Development Index (IDI)', 'Education Index',
#        'Intergalactic Development Index (IDI), Rank',
#        'Population using at least basic drinking-water services (%)',
#        'Population using at least basic sanitation services (%)',
#        'Gross capital formation (% of GGP)', 'Population, total (millions)',
#        'Population, urban (%)',
#        'Mortality rate, under-five (per 1,000 live births)',
#        'Mortality rate, infant (per 1,000 live births)',
#        'Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))',
#        'Population, ages 15–64 (millions)',
#        'Population, ages 65 and older (millions)',
#        'Life expectancy at birth, male (galactic years)',
#        'Life expectancy at birth, female (galactic years)',
#        'Population, under age 5 (millions)',
#        'Young age (0-14) dependency ratio (per 100 creatures ages 15-64)',
#        'Adolescent birth rate (births per 1,000 female creatures ages 15-19)',
#        'Total unemployment rate (female to male ratio)',
#        'Vulnerable employment (% of total employment)',
#        'Unemployment, total (% of labour force)',
#        'Employment in agriculture (% of total employment)',
#        'Labour force participation rate (% ages 15 and older)',
#        'Labour force participation rate (% ages 15 and older), female',
#        'Employment in services (% of total employment)',
#        'Labour force participation rate (% ages 15 and older), male',
#        'Employment to population ratio (% ages 15 and older)',
#        'Jungle area (% of total land area)',
#        'Share of employment in nonagriculture, female (% of total employment in nonagriculture)',
#        'Youth unemployment rate (female to male ratio)',
#        'Unemployment, youth (% ages 15–24)',
#        'Mortality rate, female grown up (per 1,000 people)',
#        'Mortality rate, male grown up (per 1,000 people)',
#        'Infants lacking immunization, red hot disease (% of one-galactic year-olds)',
#        'Infants lacking immunization, Combination Vaccine (% of one-galactic year-olds)',
#        'Gross galactic product (GGP) per capita',
#        'Gross galactic product (GGP), total',
#        'Outer Galaxies direct investment, net inflows (% of GGP)',
#        'Exports and imports (% of GGP)',
#        'Share of seats in senate (% held by female)',
#        'Natural resource depletion',
#        'Mean years of education, female (galactic years)',
#        'Mean years of education, male (galactic years)',
#        'Expected years of education, female (galactic years)',
#        'Expected years of education, male (galactic years)',
#        'Maternal mortality ratio (deaths per 100,000 live births)',
#        'Renewable energy consumption (% of total final energy consumption)',
#        'Estimated gross galactic income per capita, male',
#        'Estimated gross galactic income per capita, female',
#        'Rural population with access to electricity (%)',
#        'Domestic credit provided by financial sector (% of GGP)',
#        'Population with at least some secondary education, female (% ages 25 and older)',
#        'Population with at least some secondary education, male (% ages 25 and older)',
#        'Gross fixed capital formation (% of GGP)',
#        'Remittances, inflows (% of GGP)',
#        'Population with at least some secondary education (% ages 25 and older)',
#        'Intergalactic inbound tourists (thousands)',
#        'Gross enrolment ratio, primary (% of primary under-age population)',
#        'Respiratory disease incidence (per 100,000 people)',
#        'Interstellar phone subscriptions (per 100 people)',
#        'Interstellar Data Net users, total (% of population)',
#        'Current health expenditure (% of GGP)',
#        'Intergalactic Development Index (IDI), female',
#        'Intergalactic Development Index (IDI), male',
#        'Gender Development Index (GDI)',
#        'Intergalactic Development Index (IDI), female, Rank',
#        'Intergalactic Development Index (IDI), male, Rank',
#        'Adjusted net savings ',
#        'Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total',
#        'Private galaxy capital flows (% of GGP)',
#        'Gender Inequality Index (GII)', 'y'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (3865, 80)

# %%
df_test.shape
# Out:
# (890, 79)

# %%
msn.bar(df_train, figsize=(50, 35), color='blue')
# Out:
# <AxesSubplot:>

# %%
msn.bar(df_test,figsize=(50, 35), color='red')
plt.show()

# %% [markdown]
# ## Checking null values with heatmap

# %%
plt.figure(figsize = (30,18))
sns.heatmap(data = df_train.isnull() , cmap = "magma" , cbar = False , yticklabels=False)
plt.show()

# %%
df_train['Intergalactic Development Index (IDI), female, Rank']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 3860    124.564121
# 3861    163.664516
# 3862     66.498714
# 3863    182.249079
# 3864     57.204155
# Name: Intergalactic Development Index (IDI), female, Rank, Length: 3865, dtype: float64

# %%
df_train['galaxy'].value_counts()
# Out:
# Andromeda XXII[57]                             26
# Tucana Dwarf                                   26
# Andromeda XXIV                                 26
# Andromeda XIX[60]                              26
# Andromeda XII                                  26
#                                                ..
# Sagittarius Dwarf Irregular Galaxy (SagDIG)    17
# Aquarius Dwarf Galaxy (DDO 210)                17
# Andromeda XXI[57]                              17
# Pegasus Dwarf Irregular (DDO 216)              17
# NGC 5253                                        1
# Name: galaxy, Length: 181, dtype: int64

# %%
df_test['galaxy'].value_counts()
# Out:
# Pegasus Dwarf Irregular (DDO 216)              10
# Andromeda XXI[57]                              10
# Sagittarius Dwarf Irregular Galaxy (SagDIG)    10
# Wolf-Lundmark-Melotte (WLM, DDO 221)           10
# Andromeda X                                    10
#                                                ..
# Pisces II                                       1
# Pegasus III                                     1
# Canes Venatici II Dwarf                         1
# Leo IV Dwarf                                    1
# Boötes IV                                       1
# Name: galaxy, Length: 172, dtype: int64

# %% [markdown]
# ### Galactic year visualizaiton

# %%
plt.figure(figsize = (30,18))
sns.countplot(x=df_train['galactic year'])
# Out:
# <AxesSubplot:xlabel='galactic year', ylabel='count'>

# %%
plt.figure(figsize = (30,18))
sns.countplot(x=df_test['galactic year'])
# Out:
# <AxesSubplot:xlabel='galactic year', ylabel='count'>

# %%
plt.figure(figsize = (30,28))
df_train.plot(x='existence expectancy index', y='galactic year', style='o')  
plt.title('existence expectancy index')  
plt.xlabel('existence expectancy index')  
plt.ylabel('galactic year')  
plt.show()

# %%
plt.figure(figsize = (30,28))
df_test.plot(x='existence expectancy index', y='galactic year', style='o')  
plt.title('existence expectancy index')  
plt.xlabel('existence expectancy index')  
plt.ylabel('galactic year')  
plt.show()

# %% [markdown]
# ### Distribution of "Gross income per capita" for both datasets

# %%
import seaborn as seabornInstance
plt.figure(figsize=(14,8))
plt.tight_layout()
seabornInstance.distplot(df_train['Gross income per capita'])
# Out:
# <AxesSubplot:xlabel='Gross income per capita', ylabel='Density'>

# %%
plt.figure(figsize=(14,8))
plt.tight_layout()
seabornInstance.distplot(df_test['Gross income per capita'])
# Out:
# <AxesSubplot:xlabel='Gross income per capita', ylabel='Density'>

# %% [markdown]
# ### Distribution of "Income Index" for both datasets

# %%
plt.figure(figsize=(14,8))
plt.tight_layout()
seabornInstance.distplot(df_train['Income Index'])
# Out:
# <AxesSubplot:xlabel='Income Index', ylabel='Density'>

# %%
plt.figure(figsize=(14,8))
plt.tight_layout()
seabornInstance.distplot(df_test['Income Index'])
# Out:
# <AxesSubplot:xlabel='Income Index', ylabel='Density'>

# %% [markdown]
# ### Outlier detection for "df_train" using boxplot

# %%
plt.figure(figsize = (20,50))
ax = sns.boxplot(data=df_train, orient="h")
ax.set_title('Distribution Preprocessed Boxplots', fontsize=20)
ax.set(xscale='log')
plt.show()

# %% [markdown]
# ### Outlier detection for "df_test" using boxplot

# %%
plt.figure(figsize = (20,50))
ax = sns.boxplot(data=df_test, orient="h")
ax.set_title('Distribution Preprocessed Boxplots', fontsize=20)
ax.set(xscale='log')
plt.show()

# %% [markdown]
# ### Distribution of "Gross capital formation (% of GGP)"

# %%
plt.figure(figsize = (14,8))
sns.set_theme(style="darkgrid")
sns.displot(
    df_train, x="Gross capital formation (% of GGP)"    
)

# %% [markdown]
# ### Data Cleaning

# %%
df_train = df_train[[f for f in df_train.columns if f in df_train.iloc[:,0:11].columns or f=='y']]
df_test = df_test.iloc[:,0:11]

# %%
display(df_train.head(), df_test.head())
# Out:
#    galactic year                        galaxy  existence expectancy index  \
# 0         990025  Large Magellanic Cloud (LMC)                    0.628657
# 1         990025              Camelopardalis B                    0.818082
# 2         990025                       Virgo I                    0.659443
# 3         990025            UGC 8651 (DDO 181)                    0.555862
# 4         990025                  Tucana Dwarf                    0.991196
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      63.125200             27109.234310      0.646039
# 1                      81.004994             30166.793958      0.852246
# 2                      59.570534              8441.707353      0.499762
# 3                      52.333293                      NaN           NaN
# 4                      81.802464             81033.956906      1.131163
#
#    Expected years of education (galactic years)  \
# 0                                      8.240543
# 1                                     10.671823
# 2                                      8.840316
# 3                                           NaN
# 4                                     13.800672
#
#    Mean years of education (galactic years)  \
# 0                                       NaN
# 1                                  4.742470
# 2                                  5.583973
# 3                                       NaN
# 4                                 13.188907
#
#    Intergalactic Development Index (IDI)  Education Index  \
# 0                                    NaN              NaN
# 1                               0.833624         0.467873
# 2                               0.469110         0.363837
# 3                                    NaN              NaN
# 4                               0.910341         0.918353
#
#    Intergalactic Development Index (IDI), Rank         y
# 0                                          NaN  0.052590
# 1                                   152.522198  0.059868
# 2                                   209.813266  0.050449
# 3                                          NaN  0.049394
# 4                                    71.885345  0.154247
#    galactic year         galaxy  existence expectancy index  \
# 0        1007012        KK98 77                    0.456086
# 1        1007012  Reticulum III                    0.529835
# 2        1008016  Reticulum III                    0.560976
# 3        1007012        Segue 1                    0.565910
# 4        1013042        Virgo I                    0.588274
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      51.562543             12236.576447      0.593325
# 1                      57.228262              3431.883825      0.675407
# 2                      59.379539             27562.914252      0.594624
# 3                      59.952390             20352.232905      0.837700
# 4                      55.428320             23959.704016      0.520579
#
#    Expected years of education (galactic years)  \
# 0                                     10.414164
# 1                                      7.239485
# 2                                     11.774890
# 3                                     11.613621
# 4                                     10.392416
#
#    Mean years of education (galactic years)  \
# 0                                 10.699072
# 1                                  5.311122
# 2                                  5.937797
# 3                                 10.067882
# 4                                  6.374637
#
#    Intergalactic Development Index (IDI)  Education Index  \
# 0                               0.547114         0.556267
# 1                               0.497688         0.409969
# 2                               0.544744         0.486167
# 3                               0.691641         0.523441
# 4                               0.530676         0.580418
#
#    Intergalactic Development Index (IDI), Rank
# 0                                   232.621842
# 1                                   247.580771
# 2                                   249.798771
# 3                                   211.505060
# 4                                   234.721069

# %%
def data_cleaning(data, pct_threshold=0.5): 
    
    for col in data.columns:
        col_type = data[col].dtype
        
        if col_type != 'object':
            c_min = data[col].min()
            c_max = data[col].max()
            if 'int' in str(col_type): 
                if c_min > np.iinfo(np.uint8).min and c_max < np.iinfo(np.uint8).max:
                    data[col] = data[col].astype(np.uint8)
                elif c_min > np.iinfo(np.uint16).min and c_max < np.iinfo(np.uint16).max:
                    data[col] = data[col].astype(np.uint16)
                elif c_min > np.iinfo(np.uint32).min and c_max < np.iinfo(np.uint32).max:
                    data[col] = data[col].astype(np.uint32)
                elif c_min > np.iinfo(np.uint64).min and c_max < np.iinfo(np.uint64).max:
                    data[col] = data[col].astype(np.uint64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    data[col] = data[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    data[col] = data[col].astype(np.float32)
                else:
                    data[col] = data[col].astype(np.float64)
        
        elif col_type=='object':
            if data[col].nunique() / data[col].shape[0] < pct_threshold:  
                data[col] = data[col].astype('category') 
            else:
                continue

# %%
data_cleaning(df_train)

# %%
msn.bar(df_train, color='blue')
plt.show()

# %%
data_cleaning(df_test)

# %%
msn.bar(df_test, color='red')
plt.show()

# %%
def column_null_ratio(data):
    ratio = []
    for f in data.columns:
        n_missing = data[f].isna().sum()
        ratio.append(n_missing / data.shape[0])
    return ratio

# %%
display(column_null_ratio(df_train),
        column_null_ratio(df_test))
# Out:
# [0.0,
#  0.0,
#  0.000258732212160414,
#  0.000258732212160414,
#  0.007244501940491591,
#  0.007244501940491591,
#  0.034411384217335056,
#  0.09391979301423027,
#  0.10116429495472186,
#  0.10116429495472186,
#  0.11203104786545925,
#  0.0]
# [0.0,
#  0.0,
#  0.0056179775280898875,
#  0.0056179775280898875,
#  0.0056179775280898875,
#  0.0056179775280898875,
#  0.0056179775280898875,
#  0.008988764044943821,
#  0.008988764044943821,
#  0.008988764044943821,
#  0.011235955056179775]

# %% [markdown]
# ## Cleaning columns' names

# %%
def column_names_alter(data):
    data.rename(columns=lambda x: x.lower().replace(' ', '_').replace('-', '_').replace(',', ''), inplace=True)
    return print(f'Column names cleaned: {df_train.columns}')
column_names_alter(df_train)
column_names_alter(df_test)
# Out:
# Column names cleaned: Index(['galactic_year', 'galaxy', 'existence_expectancy_index',
#        'existence_expectancy_at_birth', 'gross_income_per_capita',
#        'income_index', 'expected_years_of_education_(galactic_years)',
#        'mean_years_of_education_(galactic_years)',
#        'intergalactic_development_index_(idi)', 'education_index',
#        'intergalactic_development_index_(idi)_rank', 'y'],
#       dtype='object')
# Column names cleaned: Index(['galactic_year', 'galaxy', 'existence_expectancy_index',
#        'existence_expectancy_at_birth', 'gross_income_per_capita',
#        'income_index', 'expected_years_of_education_(galactic_years)',
#        'mean_years_of_education_(galactic_years)',
#        'intergalactic_development_index_(idi)', 'education_index',
#        'intergalactic_development_index_(idi)_rank', 'y'],
#       dtype='object')

# %% [markdown]
# ### Removing white spaces from columns' names

# %%
def values_stripper(data):
    for f in data.columns:
        if data[f].dtype == 'O':
            data[f] = data[f].str.strip()
            print(f'The unique values for {f} variable: {df_train[f].unique()}\n')
values_stripper(df_train)            
values_stripper(df_test)

# %%
def duplicate_check_remove(data):
    num_duplicates = data.duplicated().sum()
    if num_duplicates > 0:
        print(f'The number of duplicate rows before: {num_duplicates}')
        data.drop_duplicates(inplace = True)
        print(f'The number of duplicate rows now: {data.duplicated().sum()}')
    else:
        print('There are no duplicate rows in the dataset.')
duplicate_check_remove(df_test)
duplicate_check_remove(df_train)
# Out:
# There are no duplicate rows in the dataset.
# There are no duplicate rows in the dataset.

# %%
display(df_train['galactic_year'].value_counts().to_frame().T,  
        df_train['galaxy'].value_counts().to_frame().T)
# Out:
#                990025   999000   1006009  1005006  1004004  991020   1002001  \
# galactic_year      181      180      180      180      180      180      180
#
#                1001000  1000000  1003002  998001   997002   996004   995006   \
# galactic_year      180      180      180      180      180      180      180
#
#                994009   993012   992016   1007012  1008016  1009020  1010025  \
# galactic_year      180      180      180       90       90       90       90
#
#                1011030  1012036  1013042  1014049  1015056
# galactic_year       90       90       89       88       87
#         Andromeda XII  Andromeda XIX[60]  Andromeda XXII[57]  Tucana Dwarf  \
# galaxy             26                 26                  26            26
#
#         Andromeda XXIV  Pegasus III  Pisces IV (Andromeda XIV)  Eridanus II  \
# galaxy              26           25                         25           25
#
#         Cassiopeia III (Andromeda XXXII)  Cetus III  \
# galaxy                                25         25
#
#         Phoenix Dwarf Galaxy (P 6830)  Pisces V (Andromeda XVI)  Boötes IV  \
# galaxy                             25                        25         25
#
#         Andromeda XXVIII  Cetus Dwarf  Andromeda XXV  Pisces II  \
# galaxy                25           25             25         25
#
#         Triangulum Galaxy (M33)  Canes Venatici II Dwarf  Pisces Dwarf  \
# galaxy                       25                       25            25
#
#         IC 1613 (UGC 668)  Andromeda XX  M32 (NGC 221)  \
# galaxy                 25            25             25
#
#         Pegasus Dwarf Sph (And VI)  Andromeda XV  Leo IV Dwarf  \
# galaxy                          25            25            25
#
#         NGC 147 (DDO 3)  Andromeda XXIII  Andromeda VIII  Andromeda II  \
# galaxy               25               25              25            25
#
#         IC 10 (UGC 192)  ESO 321-014[70]  NGC 404  KKH 12  NGC 5206  \
# galaxy               25               24       24      24        24
#
#         Dwingeloo 2  UGC 8651 (DDO 181)  Tucana III  KK98 35  Indus II  \
# galaxy           24                  24          24       24        24
#
#         ESO 540-030 (KDG 2)  NGC 2366  Draco II  Grus I  Grus II  NGC 1560  \
# galaxy                   24        24        24      24       24        24
#
#         Horologium I  Horologium II  Maffei 2  FM2000 1  ...  Tucana II  MB 3  \
# galaxy            24             24        24        24  ...         19    19
#
#         Maffei 1  Hydrus I  Segue 2  HIPASS J1247-77  UGC 8833  Triangulum II  \
# galaxy        19        19       19               19        19             19
#
#         ESO 540-032  ESO 383-087 (ISG 39)  NGC 247  ESO 325-11  NGC 3741  \
# galaxy           19                    19       19          19        19
#
#         ESO 274-01[70]  Large Magellanic Cloud (LMC)  NGC 4214 (UGC 7278)  \
# galaxy              19                            19                   19
#
#         Segue 1  Andromeda Galaxy (M31)  Columba I  Andromeda XI  \
# galaxy       19                      18         18            18
#
#         Andromeda XXIX  Andromeda XXVI  Andromeda V  \
# galaxy              18              18           18
#
#         Barnard's Galaxy (NGC 6822)  Canes Venatici I Dwarf  \
# galaxy                           18                      18
#
#         Cassiopeia Dwarf (Cas dSph, Andromeda VII)  \
# galaxy                                          18
#
#         Cassiopeia II (Andromeda XXX)  Pisces III (Andromeda XIII)  \
# galaxy                             18                           18
#
#         Fornax Dwarf (E356-G04)  Hydra II  Andromeda I  \
# galaxy                       18        18           18
#
#         Lacerta I (Andromeda XXXI)  Leo A (Leo III, DDO 69)  \
# galaxy                          18                       18
#
#         Leo I Dwarf (DDO 74, UGC 5470)  Leo II Dwarf (Leo B, DDO 93)  \
# galaxy                              18                            18
#
#         Leo T Dwarf  Leo V Dwarf  M110 (NGC 205)  NGC 185  Andromeda IX  \
# galaxy           18           18              18       18            18
#
#         Andromeda III  Perseus I (Andromeda XXXIII)  Andromeda XVII  \
# galaxy             18                            18              18
#
#         Andromeda X  Sagittarius Dwarf Irregular Galaxy (SagDIG)  \
# galaxy           17                                           17
#
#         Andromeda XXI[57]  Aquarius Dwarf Galaxy (DDO 210)  \
# galaxy                 17                               17
#
#         Pegasus Dwarf Irregular (DDO 216)  \
# galaxy                                 17
#
#         Wolf-Lundmark-Melotte (WLM, DDO 221)  NGC 5253
# galaxy                                    17         1
#
# [1 rows x 181 columns]

# %% [markdown]
# ## Check for if there are same categories in both train and test data

# %%
separate_gal = [f for f in set(df_test['galaxy'].to_list()) 
            if f not in set(df_train['galaxy'].to_list())]
print(f'Test dataset contains {len(separate_gal)} values that train does not')
# Out:
# Test dataset contains 0 values that train does not

# %%
separate_year = [f for f in set(df_test['galactic_year'].to_list())  
            if f not in set(df_train['galactic_year'].to_list())]
print(f'Test dataset contains {len(separate_year)} values that train does not')
# Out:
# Test dataset contains 1 values that train does not

# %%
df_test[df_test['galaxy']=='NGC 5253']
# Out:
# Empty DataFrame
# Columns: [galactic_year, galaxy, existence_expectancy_index, existence_expectancy_at_birth, gross_income_per_capita, income_index, expected_years_of_education_(galactic_years), mean_years_of_education_(galactic_years), intergalactic_development_index_(idi), education_index, intergalactic_development_index_(idi)_rank]
# Index: []

# %%
df_train = df_train[df_train['galaxy']!='NGC 5253']

# %%
df_train['galactic_year'] = df_train['galactic_year'].astype('O') 
df_test['galactic_year'] = df_test['galactic_year'].astype('O')

# %%
class KFoldTargetEncoderTrain(base.BaseEstimator, base.TransformerMixin):
   
    def __init__(self,colnames,targetName,
                  n_fold=5, verbosity=True,
                  discardOriginal_col=False):
        self.colnames = colnames
        self.targetName = targetName
        self.n_fold = n_fold
        self.verbosity = verbosity
        self.discardOriginal_col = discardOriginal_col
        
    def fit(self, X, y=None):
        return self
    
    def transform(self,X):        
        assert(type(self.targetName) == str)
        assert(type(self.colnames) == str)
        assert(self.colnames in X.columns)
        assert(self.targetName in X.columns)       
        
        mean_of_target = X[self.targetName].mean()
        kf = KFold(n_splits = self.n_fold,
                   shuffle = True)        
        col_mean_name = self.colnames + '_' + 'Kfold_Target_Enc'
        X[col_mean_name] = np.nan       
        
        for tr_ind, val_ind in kf.split(X):
            X_tr, X_val = X.iloc[tr_ind], X.iloc[val_ind]
            X.loc[X.index[val_ind], col_mean_name] = X_val[self.colnames].map(X_tr.groupby(self.colnames)[self.targetName].mean())
            X[col_mean_name].fillna(mean_of_target, inplace = True)  #Fill in the place that has become nan with the global mean
            
        if self.verbosity:            
            encoded_feature = X[col_mean_name].values
            print('Correlation between the new feature, {} and, {} is {}.'.format(col_mean_name,self.targetName, 
                                                                                  np.corrcoef(X[self.targetName].values,encoded_feature)[0][1]))
        if self.discardOriginal_col:
            X = X.drop(self.targetName, axis=1)
        return X

# %% [markdown]
# ### For train dataset

# %%
for f in df_train.columns[0:2]:
    targetc = KFoldTargetEncoderTrain(f, 'y', n_fold=5)
    df_t = targetc.fit_transform(df_train)
# Out:
# Correlation between the new feature, galactic_year_Kfold_Target_Enc and, y is -0.09193567265962783.
# Correlation between the new feature, galaxy_Kfold_Target_Enc and, y is 0.9595724132409045.

# %%
df_train = pd.concat([df_train.iloc[:,2:].drop('y', axis=1), df_train['y']], axis=1)

# %%
df_train.head()
# Out:
#    existence_expectancy_index  existence_expectancy_at_birth  \
# 0                    0.628418                       63.12500
# 1                    0.817871                       81.00000
# 2                    0.659668                       59.56250
# 3                    0.555664                       52.34375
# 4                    0.991211                       81.81250
#
#    gross_income_per_capita  income_index  \
# 0             27109.234375      0.645996
# 1             30166.794922      0.852051
# 2              8441.707031      0.499756
# 3                      NaN           NaN
# 4             81033.953125      1.130859
#
#    expected_years_of_education_(galactic_years)  \
# 0                                      8.242188
# 1                                     10.671875
# 2                                      8.843750
# 3                                           NaN
# 4                                     13.796875
#
#    mean_years_of_education_(galactic_years)  \
# 0                                       NaN
# 1                                  4.742188
# 2                                  5.582031
# 3                                       NaN
# 4                                 13.187500
#
#    intergalactic_development_index_(idi)  education_index  \
# 0                                    NaN              NaN
# 1                               0.833496         0.467773
# 2                               0.468994         0.363770
# 3                                    NaN              NaN
# 4                               0.910156         0.918457
#
#    intergalactic_development_index_(idi)_rank  galactic_year_Kfold_Target_Enc  \
# 0                                         NaN                        0.079956
# 1                                     152.500                        0.083862
# 2                                     209.875                        0.083862
# 3                                         NaN                        0.081726
# 4                                      71.875                        0.083069
#
#    galaxy_Kfold_Target_Enc         y
# 0                 0.046692  0.052582
# 1                 0.057617  0.059875
# 2                 0.042084  0.050446
# 3                 0.041016  0.049408
# 4                 0.216309  0.154297

# %% [markdown]
# ### For test dataset

# %%
class KFoldTargetEncoderTest(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self,train,colNames,encodedName):
        
        self.train = train
        self.colNames = colNames
        self.encodedName = encodedName
        
        
    def fit(self, X, y=None):
        return self

    def transform(self,X):


        mean = self.train[[self.colNames,self.encodedName]].groupby(self.colNames).mean().reset_index() 
        
        dd = {}
        for index, row in mean.iterrows():
            dd[row[self.colNames]] = row[self.encodedName]

        
        X[self.encodedName] = X[self.colNames]
        X = X.replace({self.encodedName: dd})

        return X

# %%
test_targetc = KFoldTargetEncoderTest(df_t, 'galactic_year', 'galactic_year_Kfold_Target_Enc')
df_test = test_targetc.fit_transform(df_test)
test_targetc = KFoldTargetEncoderTest(df_t, 'galaxy', 'galaxy_Kfold_Target_Enc')
df_test = test_targetc.fit_transform(df_test)

# %%
df_test = df_test.iloc[:,2:]

# %%
df_test
# Out:
#      existence_expectancy_index  existence_expectancy_at_birth  \
# 0                      0.456055                       51.56250
# 1                      0.529785                       57.21875
# 2                      0.561035                       59.37500
# 3                      0.565918                       59.93750
# 4                      0.588379                       55.43750
# ..                          ...                            ...
# 885                         NaN                            NaN
# 886                         NaN                            NaN
# 887                         NaN                            NaN
# 888                         NaN                            NaN
# 889                         NaN                            NaN
#
#      gross_income_per_capita  income_index  \
# 0               12236.576172      0.593262
# 1                3431.883789      0.675293
# 2               27562.914062      0.594727
# 3               20352.232422      0.837891
# 4               23959.703125      0.520508
# ..                       ...           ...
# 885                      NaN           NaN
# 886                      NaN           NaN
# 887                      NaN           NaN
# 888                      NaN           NaN
# 889                      NaN           NaN
#
#      expected_years_of_education_(galactic_years)  \
# 0                                       10.414062
# 1                                        7.238281
# 2                                       11.773438
# 3                                       11.617188
# 4                                       10.390625
# ..                                            ...
# 885                                           NaN
# 886                                           NaN
# 887                                           NaN
# 888                                           NaN
# 889                                           NaN
#
#      mean_years_of_education_(galactic_years)  \
# 0                                   10.695312
# 1                                    5.312500
# 2                                    5.937500
# 3                                   10.070312
# 4                                    6.375000
# ..                                        ...
# 885                                       NaN
# 886                                       NaN
# 887                                       NaN
# 888                                       NaN
# 889                                       NaN
#
#      intergalactic_development_index_(idi)  education_index  \
# 0                                 0.546875         0.556152
# 1                                 0.497803         0.409912
# 2                                 0.544922         0.486084
# 3                                 0.691406         0.523438
# 4                                 0.530762         0.580566
# ..                                     ...              ...
# 885                                    NaN              NaN
# 886                                    NaN              NaN
# 887                                    NaN              NaN
# 888                                    NaN              NaN
# 889                                    NaN              NaN
#
#      intergalactic_development_index_(idi)_rank  \
# 0                                       232.625
# 1                                       247.625
# 2                                       249.750
# 3                                       211.500
# 4                                       234.750
# ..                                          ...
# 885                                         NaN
# 886                                         NaN
# 887                                         NaN
# 888                                         NaN
# 889                                         NaN
#
#      galactic_year_Kfold_Target_Enc  galaxy_Kfold_Target_Enc
# 0                      8.132189e-02                 0.046109
# 1                      8.132189e-02                 0.042839
# 2                      8.128052e-02                 0.042839
# 3                      8.132189e-02                 0.043467
# 4                      9.525050e-02                 0.042113
# ..                              ...                      ...
# 885                    1.016064e+06                 0.045176
# 886                    1.016064e+06                 0.053049
# 887                    1.016064e+06                 0.075626
# 888                    1.016064e+06                 0.066907
# 889                    1.016064e+06                 0.046109
#
# [890 rows x 11 columns]

# %% [markdown]
# ### Imputing train dataset

# %%
imputer = IterativeImputer(random_state=123, n_nearest_features=15, max_iter=3693, verbose = 1)

# %%
df_imputed = imputer.fit_transform(df_train)
df_imputed = pd.DataFrame(df_imputed, columns=df_train.columns)

df_imputed
# Out:
# [IterativeImputer] Completing matrix with shape (3864, 12)
# [IterativeImputer] Change: 3520.757191966776, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 6213.225629697357, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 5584.469438685923, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 2940.9158827629017, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 1812.4575176837855, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 1203.266755354334, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 838.4462182029949, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 601.9110673227858, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 440.0245665318105, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 325.14552937631515, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 241.7443967038421, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 180.36231159347582, scaled tolerance: 151.0726875
# [IterativeImputer] Change: 134.82679071989057, scaled tolerance: 151.0726875
# [IterativeImputer] Early stopping criterion reached.
#       existence_expectancy_index  existence_expectancy_at_birth  \
# 0                       0.628418                       63.12500
# 1                       0.817871                       81.00000
# 2                       0.659668                       59.56250
# 3                       0.555664                       52.34375
# 4                       0.991211                       81.81250
# ...                          ...                            ...
# 3859                    1.029297                       82.81250
# 3860                    0.937988                       75.87500
# 3861                    1.036133                       93.56250
# 3862                    0.938965                       78.25000
# 3863                    1.032227                       91.62500
#
#       gross_income_per_capita  income_index  \
# 0                27109.234375      0.645996
# 1                30166.794922      0.852051
# 2                 8441.707031      0.499756
# 3                14385.099581      0.540953
# 4                81033.953125      1.130859
# ...                       ...           ...
# 3859             34310.472656      0.854980
# 3860             36899.066406      0.929688
# 3861             37002.976562      1.084961
# 3862             28180.458984      0.687500
# 3863             73109.218750      1.208008
#
#       expected_years_of_education_(galactic_years)  \
# 0                                         8.242188
# 1                                        10.671875
# 2                                         8.843750
# 3                                         9.497782
# 4                                        13.796875
# ...                                            ...
# 3859                                     18.578125
# 3860                                     16.156250
# 3861                                     21.062500
# 3862                                      9.390625
# 3863                                     18.906250
#
#       mean_years_of_education_(galactic_years)  \
# 0                                     5.887001
# 1                                     4.742188
# 2                                     5.582031
# 3                                     5.807682
# 4                                    13.187500
# ...                                        ...
# 3859                                 10.554688
# 3860                                  9.148438
# 3861                                 16.656250
# 3862                                  8.906250
# 3863                                 16.203125
#
#       intergalactic_development_index_(idi)  education_index  \
# 0                                  0.547955         0.442086
# 1                                  0.833496         0.467773
# 2                                  0.468994         0.363770
# 3                                  0.488598         0.452249
# 4                                  0.910156         0.918457
# ...                                     ...              ...
# 3859                               0.906738         0.862793
# 3860                               0.865723         0.747559
# 3861                               0.983887         1.100586
# 3862                               0.735840         0.602539
# 3863                               1.171875         1.084961
#
#       intergalactic_development_index_(idi)_rank  \
# 0                                     189.948447
# 1                                     152.500000
# 2                                     209.875000
# 3                                     210.830175
# 4                                      71.875000
# ...                                          ...
# 3859                                  144.875000
# 3860                                  164.750000
# 3861                                   63.718750
# 3862                                  216.750000
# 3863                                   63.937500
#
#       galactic_year_Kfold_Target_Enc  galaxy_Kfold_Target_Enc         y
# 0                           0.079956                 0.046692  0.052582
# 1                           0.083862                 0.057617  0.059875
# 2                           0.083862                 0.042084  0.050446
# 3                           0.081726                 0.041016  0.049408
# 4                           0.083069                 0.216309  0.154297
# ...                              ...                      ...       ...
# 3859                        0.087341                 0.065308  0.042328
# 3860                        0.087341                 0.055939  0.036713
# 3861                        0.070984                 0.103455  0.166260
# 3862                        0.087341                 0.046417  0.024185
# 3863                        0.082458                 0.124329  0.100098
#
# [3864 rows x 12 columns]

# %%
df_train=df_imputed

# %%
df_train.isnull().sum()
# Out:
# existence_expectancy_index                      0
# existence_expectancy_at_birth                   0
# gross_income_per_capita                         0
# income_index                                    0
# expected_years_of_education_(galactic_years)    0
# mean_years_of_education_(galactic_years)        0
# intergalactic_development_index_(idi)           0
# education_index                                 0
# intergalactic_development_index_(idi)_rank      0
# galactic_year_Kfold_Target_Enc                  0
# galaxy_Kfold_Target_Enc                         0
# y                                               0
# dtype: int64

# %% [markdown]
# ### Imputing test dataset

# %%
df_imputed = imputer.fit_transform(df_test)
df_imputed = pd.DataFrame(df_imputed, columns=df_test.columns)
# Out:
# [IterativeImputer] Completing matrix with shape (890, 11)
# [IterativeImputer] Change: 3492.057898967193, scaled tolerance: 1016.064
# [IterativeImputer] Change: 680.8079846814604, scaled tolerance: 1016.064
# [IterativeImputer] Early stopping criterion reached.

# %%
df_test=df_imputed

# %% [markdown]
# ### Checking for null values for both datasets

# %%
df_test.isnull().sum()
# Out:
# existence_expectancy_index                      0
# existence_expectancy_at_birth                   0
# gross_income_per_capita                         0
# income_index                                    0
# expected_years_of_education_(galactic_years)    0
# mean_years_of_education_(galactic_years)        0
# intergalactic_development_index_(idi)           0
# education_index                                 0
# intergalactic_development_index_(idi)_rank      0
# galactic_year_Kfold_Target_Enc                  0
# galaxy_Kfold_Target_Enc                         0
# dtype: int64

# %%
display(df_train.isnull().sum(), df_test.isnull().sum())
# Out:
# existence_expectancy_index                      0
# existence_expectancy_at_birth                   0
# gross_income_per_capita                         0
# income_index                                    0
# expected_years_of_education_(galactic_years)    0
# mean_years_of_education_(galactic_years)        0
# intergalactic_development_index_(idi)           0
# education_index                                 0
# intergalactic_development_index_(idi)_rank      0
# galactic_year_Kfold_Target_Enc                  0
# galaxy_Kfold_Target_Enc                         0
# y                                               0
# dtype: int64
# existence_expectancy_index                      0
# existence_expectancy_at_birth                   0
# gross_income_per_capita                         0
# income_index                                    0
# expected_years_of_education_(galactic_years)    0
# mean_years_of_education_(galactic_years)        0
# intergalactic_development_index_(idi)           0
# education_index                                 0
# intergalactic_development_index_(idi)_rank      0
# galactic_year_Kfold_Target_Enc                  0
# galaxy_Kfold_Target_Enc                         0
# dtype: int64

# %% [markdown]
# ### Checking null values with heatmap for both datasets

# %%
plt.figure(figsize = (30,18))
sns.heatmap(data = df_train.isnull() , cmap = "magma" , cbar = False , yticklabels=False)
plt.show()

# %%
plt.figure(figsize = (30,18))
sns.heatmap(data = df_test.isnull() , cmap = "magma" , cbar = False , yticklabels=False)
plt.show()

# %%
df_train.head().T
# Out:
#                                                          0             1  \
# existence_expectancy_index                        0.628418      0.817871
# existence_expectancy_at_birth                    63.125000     81.000000
# gross_income_per_capita                       27109.234375  30166.794922
# income_index                                      0.645996      0.852051
# expected_years_of_education_(galactic_years)      8.242188     10.671875
# mean_years_of_education_(galactic_years)          5.887001      4.742188
# intergalactic_development_index_(idi)             0.547955      0.833496
# education_index                                   0.442086      0.467773
# intergalactic_development_index_(idi)_rank      189.948447    152.500000
# galactic_year_Kfold_Target_Enc                    0.079956      0.083862
# galaxy_Kfold_Target_Enc                           0.046692      0.057617
# y                                                 0.052582      0.059875
#
#                                                         2             3  \
# existence_expectancy_index                       0.659668      0.555664
# existence_expectancy_at_birth                   59.562500     52.343750
# gross_income_per_capita                       8441.707031  14385.099581
# income_index                                     0.499756      0.540953
# expected_years_of_education_(galactic_years)     8.843750      9.497782
# mean_years_of_education_(galactic_years)         5.582031      5.807682
# intergalactic_development_index_(idi)            0.468994      0.488598
# education_index                                  0.363770      0.452249
# intergalactic_development_index_(idi)_rank     209.875000    210.830175
# galactic_year_Kfold_Target_Enc                   0.083862      0.081726
# galaxy_Kfold_Target_Enc                          0.042084      0.041016
# y                                                0.050446      0.049408
#
#                                                          4
# existence_expectancy_index                        0.991211
# existence_expectancy_at_birth                    81.812500
# gross_income_per_capita                       81033.953125
# income_index                                      1.130859
# expected_years_of_education_(galactic_years)     13.796875
# mean_years_of_education_(galactic_years)         13.187500
# intergalactic_development_index_(idi)             0.910156
# education_index                                   0.918457
# intergalactic_development_index_(idi)_rank       71.875000
# galactic_year_Kfold_Target_Enc                    0.083069
# galaxy_Kfold_Target_Enc                           0.216309
# y                                                 0.154297

# %%
df_test.head().T
# Out:
#                                                          0            1  \
# existence_expectancy_index                        0.456055     0.529785
# existence_expectancy_at_birth                    51.562500    57.218750
# gross_income_per_capita                       12236.576172  3431.883789
# income_index                                      0.593262     0.675293
# expected_years_of_education_(galactic_years)     10.414062     7.238281
# mean_years_of_education_(galactic_years)         10.695312     5.312500
# intergalactic_development_index_(idi)             0.546875     0.497803
# education_index                                   0.556152     0.409912
# intergalactic_development_index_(idi)_rank      232.625000   247.625000
# galactic_year_Kfold_Target_Enc                    0.081322     0.081322
# galaxy_Kfold_Target_Enc                           0.046109     0.042839
#
#                                                          2             3  \
# existence_expectancy_index                        0.561035      0.565918
# existence_expectancy_at_birth                    59.375000     59.937500
# gross_income_per_capita                       27562.914062  20352.232422
# income_index                                      0.594727      0.837891
# expected_years_of_education_(galactic_years)     11.773438     11.617188
# mean_years_of_education_(galactic_years)          5.937500     10.070312
# intergalactic_development_index_(idi)             0.544922      0.691406
# education_index                                   0.486084      0.523438
# intergalactic_development_index_(idi)_rank      249.750000    211.500000
# galactic_year_Kfold_Target_Enc                    0.081281      0.081322
# galaxy_Kfold_Target_Enc                           0.042839      0.043467
#
#                                                          4
# existence_expectancy_index                        0.588379
# existence_expectancy_at_birth                    55.437500
# gross_income_per_capita                       23959.703125
# income_index                                      0.520508
# expected_years_of_education_(galactic_years)     10.390625
# mean_years_of_education_(galactic_years)          6.375000
# intergalactic_development_index_(idi)             0.530762
# education_index                                   0.580566
# intergalactic_development_index_(idi)_rank      234.750000
# galactic_year_Kfold_Target_Enc                    0.095251
# galaxy_Kfold_Target_Enc                           0.042113

# %% [markdown]
# ### Distribution of "Intergalactic Development Index" for train and test datasets

# %%
plt.subplot(1, 2, 2)
plt.hist(df_train['intergalactic_development_index_(idi)'])
plt.title(label = 'Distribution of Intergalactic Development Index', fontsize = 8)
plt.xlabel(xlabel = 'Values', fontsize = 16)
plt.ylabel(ylabel = 'Count', fontsize = 16)

plt.subplot(1, 2, 1)
plt.hist(df_train['intergalactic_development_index_(idi)_rank'])
plt.title(label = 'Distribution of Intergalactic Development Index Rank', fontsize = 8)
plt.xlabel(xlabel = 'Values', fontsize = 16)
plt.ylabel(ylabel = 'Count', fontsize = 16)
plt.show()

# %% [markdown]
# ##### Heatmap for "pearson correlation"

# %%
plt.figure(figsize = (30,18))
sns.heatmap(df_train.corr(method='pearson'), annot=True)
plt.show()

# %% [markdown]
# ### Distributions of different features in "train dataset"

# %%
df_train.hist(figsize=(30,100), layout=(20,4))
plt.show()

# %% [markdown]
# ### Distributions of different features in "test dataset"

# %%
df_test.hist(figsize=(30,100), layout=(20,4))
plt.show()

# %% [markdown]
# ## Modelling with XGB Regressor

# %% [markdown]
# ### Scaling is important before modelling, for this reason, I did Robust Scaling for both datasets

# %%
scaler = RobustScaler()
df_train.iloc[:,:-1] = scaler.fit_transform(df_train.iloc[:,:-1])
df_train = pd.DataFrame(df_train)

# %%
scaler = RobustScaler()
df_test.iloc[:,:] = scaler.fit_transform(df_test.iloc[:,:])
df_test = pd.DataFrame(df_test)

# %%
df_train.head()
# Out:
#    existence_expectancy_index  existence_expectancy_at_birth  \
# 0                   -1.213603                      -1.085470
# 1                   -0.388948                       0.136752
# 2                   -1.077577                      -1.329060
# 3                   -1.530287                      -1.822650
# 4                    0.365569                       0.192308
#
#    gross_income_per_capita  income_index  \
# 0                 0.032627     -0.617243
# 1                 0.214330      0.085798
# 2                -1.076737     -1.116202
# 3                -0.723536     -0.975639
# 4                 3.237238      1.037068
#
#    expected_years_of_education_(galactic_years)  \
# 0                                     -1.466667
# 1                                     -0.928139
# 2                                     -1.333333
# 3                                     -1.188370
# 4                                     -0.235498
#
#    mean_years_of_education_(galactic_years)  \
# 0                                 -0.831193
# 1                                 -1.056764
# 2                                 -0.891283
# 3                                 -0.846822
# 4                                  0.607273
#
#    intergalactic_development_index_(idi)  education_index  \
# 0                              -1.007080        -1.029177
# 1                               0.085981        -0.942005
# 2                              -1.309346        -1.294946
# 3                              -1.234302        -0.994689
# 4                               0.379439         0.587407
#
#    intergalactic_development_index_(idi)_rank  galactic_year_Kfold_Target_Enc  \
# 0                                    0.607179                       -0.773585
# 1                                    0.139165                        0.433962
# 2                                    0.856212                        0.433962
# 3                                    0.868150                       -0.226415
# 4                                   -0.868451                        0.188679
#
#    galaxy_Kfold_Target_Enc         y
# 0                -0.249079  0.052582
# 1                 0.014738  0.059875
# 2                -0.360354  0.050446
# 3                -0.386146  0.049408
# 4                 3.846721  0.154297

# %%
df_test.head()
# Out:
#    existence_expectancy_index  existence_expectancy_at_birth  \
# 0                   -2.594805                      -2.402516
# 1                   -2.202597                      -1.947170
# 2                   -2.036364                      -1.773585
# 3                   -2.010390                      -1.728302
# 4                   -1.890909                      -2.090566
#
#    gross_income_per_capita  income_index  \
# 0                -0.817126     -0.962393
# 1                -1.262501     -0.675214
# 2                -0.041861     -0.957265
# 3                -0.406605     -0.105983
# 4                -0.224125     -1.217094
#
#    expected_years_of_education_(galactic_years)  \
# 0                                     -1.290117
# 1                                     -1.992492
# 2                                     -0.989469
# 3                                     -1.024026
# 4                                     -1.295300
#
#    mean_years_of_education_(galactic_years)  \
# 0                                 -0.108578
# 1                                 -1.106044
# 2                                 -0.990228
# 3                                 -0.224394
# 4                                 -0.909157
#
#    intergalactic_development_index_(idi)  education_index  \
# 0                              -1.192950        -0.856796
# 1                              -1.379406        -1.341424
# 2                              -1.200371        -1.088997
# 3                              -0.643785        -0.965210
# 4                              -1.254174        -0.775890
#
#    intergalactic_development_index_(idi)_rank  galactic_year_Kfold_Target_Enc  \
# 0                                    0.899900                        0.000000
# 1                                    1.060596                        0.000000
# 2                                    1.083361                       -0.002836
# 3                                    0.673586                        0.000000
# 4                                    0.922665                        0.954902
#
#    galaxy_Kfold_Target_Enc
# 0                -0.279976
# 1                -0.359914
# 2                -0.359914
# 3                -0.344562
# 4                -0.377652

# %%
X = df_train.drop("y",axis=1)
y = df_train.y

# %% [markdown]
# ### Train, test splitting

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,shuffle=True,random_state=123)

# %%
xgb_model = XGBRegressor()
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

# %% [markdown]
# ### Checking results with scores

# %%
print("r2 eror rate :",r2_score(y_test,y_pred))
print("MAPE :",mean_absolute_percentage_error(y_test,y_pred))
print("MAE :",mean_absolute_error(y_test,y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 eror rate : 0.94669978747125
# MAPE : 0.06578202815492785
# MAE : 0.005293290254435149
# RMSE 0.01466753570387276

# %% [markdown]
# ### Predicting for test dataset

# %%
new_preds = xgb_model.predict(df_test)

# %%
df_test['new_preds'] = pd.Series(new_preds).to_frame()

# %%
plt.figure(figsize = (30,18))
sns.displot(df_test['new_preds'])
plt.show()

# %%
# from sklearn.neighbors import KNeighborsRegressor
# neigh = KNeighborsRegressor(n_neighbors=5)
# neigh.fit(X, y)

# KNeighborsRegressor(...)
# print(neigh.predict([[1.5]]))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %%
model1 = LinearRegression()
model2 = SVR()
model3 = DecisionTreeRegressor()

# %%
model1.fit(X_train, y_train)
model2.fit(X_train, y_train)
model3.fit(X_train, y_train);

# %%
model1_pred = model1.predict(X_test)
model2_pred = model2.predict(X_test)
model3_pred = model3.predict(X_test)

# %%
from sklearn.metrics import r2_score

print(r2_score(y_test, model1_pred))
print(r2_score(y_test, model2_pred))
print(r2_score(y_test, model3_pred))
# Out:
# 0.9108961209718465
# 0.0036864027770537877
# 0.8373026919828945

# %%
from sklearn.ensemble import VotingRegressor

estimators = [('lr', model1), ('svr', model2), ('dt', model3)]
voting_reg = VotingRegressor(estimators)

# %%
voting_reg.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()), ('svr', SVR()),
#                             ('dt', DecisionTreeRegressor())])

# %%
voting_reg_pred = voting_reg.predict(X_test)

print(r2_score(y_test, voting_reg_pred))
# Out:
# 0.8217251177964332

# %%
estimators = [('lr', model1), ('svr', model2), ('dt', model3)]
voting_reg = VotingRegressor(estimators, weights=[0.3, 0.1, 0.6])

voting_reg.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()), ('svr', SVR()),
#                             ('dt', DecisionTreeRegressor())],
#                 weights=[0.3, 0.1, 0.6])

# %%
voting_reg_pred = voting_reg.predict(X_test)
print(r2_score(y_test, voting_reg_pred))
# Out:
# 0.9082166943744451

# %% [markdown]
# ### Task 2

# %%
index = df_test['new_preds']
pot_inc = -np.log(index+0.01)+3
p2= pot_inc**2
df_test["p2"] = p2

# %%
dd = df_test.drop(df_test.iloc[:, 0:11],axis = 1)
dd
# Out:
#      new_preds         p2
# 0     0.045435  34.722004
# 1     0.046221  34.556454
# 2     0.044538  34.914646
# 3     0.040658  35.792263
# 4     0.045991  34.604538
# ..         ...        ...
# 885   0.023518  40.904739
# 886   0.036148  36.916504
# 887   0.072946  30.135365
# 888   0.055459  32.790863
# 889   0.025114  40.311726
#
# [890 rows x 2 columns]

# %%
dd = dd.sort_values('p2',ascending=False)
dd = dd.reset_index(drop=False)

# %%
dd['opt_pred']=0

# %%
dd
# Out:
#      index  new_preds         p2  opt_pred
# 0       88   0.015855  44.292625         0
# 1       57   0.019226  42.676228         0
# 2      138   0.020164  42.264179         0
# 3      202   0.020454  42.140049         0
# 4       41   0.020535  42.105713         0
# ..     ...        ...        ...       ...
# 885    873   0.364218  15.863626         0
# 886    730   0.365441  15.837643         0
# 887    836   0.400876  15.127930         0
# 888    583   0.432198  14.561845         0
# 889    772   0.436820  14.482591         0
#
# [890 rows x 4 columns]

# %%
y_pred=dd.new_preds
x = np.arange(y_pred.min(),y_pred.max(),0.01)
plt.figure(figsize=(25,10))
plt.hist(y_pred,bins=x)
plt.title('Y_pred Histogram',fontsize=20)
plt.xlabel('y_pred',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(x)
plt.show()

# %%
n = 340

dd.opt_pred[:n]=100
dd.opt_pred[n:] = 0
c=100
alpha = 0.62685
for i in range(n,374):
    if c>=alpha: 
        c=c-alpha
        dd.loc[i,'opt_pred'] =c
alpha=0.067345
for i in range(374,455):
    if c>=alpha:
        c=c-alpha
        dd.loc[i,'opt_pred'] =c
    else:
        dd.loc[i,'opt_pred'] = 0
alpha = 0.03
for i in range(455,465):
    if c>=alpha: 
        c=c-alpha
        dd.loc[i,'opt_pred'] =c
alpha=0.4339465
for i in range(465,890):
    if c>=alpha: 
        c=c-alpha
        dd.loc[i,'opt_pred'] =c
    else:
        dd.loc[i,'opt_pred'] = 0

print(dd.opt_pred.sum())
# Out:
# 49999.995680999906

# %%
dd['likely_inc'] = dd.opt_pred*(dd.p2**2)/1000
print(dd.opt_pred.sum())
dd.likely_inc.sum()
# Out:
# 49999.995680999906
# 59382.337301907086

# %%
dd
# Out:
#      index  new_preds         p2  opt_pred  likely_inc
# 0       88   0.015855  44.292625     100.0  196.183667
# 1       57   0.019226  42.676228     100.0  182.126038
# 2      138   0.020164  42.264179     100.0  178.626086
# 3      202   0.020454  42.140049     100.0  177.578369
# 4       41   0.020535  42.105713     100.0  177.289111
# ..     ...        ...        ...       ...         ...
# 885    873   0.364218  15.863626       0.0    0.000000
# 886    730   0.365441  15.837643       0.0    0.000000
# 887    836   0.400876  15.127930       0.0    0.000000
# 888    583   0.432198  14.561845       0.0    0.000000
# 889    772   0.436820  14.482591       0.0    0.000000
#
# [890 rows x 5 columns]

# %%
print("sum",dd.opt_pred.sum())
print("left", (50000-dd.opt_pred.sum())) 
print("likely_inc",dd[dd.likely_inc<0.7]['opt_pred'].sum())
# Out:
# sum 49999.995680999906
# left 0.004319000094255898
# likely_inc 0.4922324999992711

# %%
plt.figure(figsize = (30,18))
plt.plot(dd.new_preds)
plt.plot(dd.opt_pred/100,color="red")
plt.show()

# %% [markdown]
# ### Submission part

# %%
dd=dd.sort_values('index',ascending=True)
dd=dd.reset_index(drop=True)

# %%
dd.rename(columns = {'new_preds':'pred'}, inplace=True)
dd
# Out:
#      index      pred         p2    opt_pred  likely_inc
# 0        0  0.045435  34.722004  100.000000  120.561755
# 1        1  0.046221  34.556454  100.000000  119.414844
# 2        2  0.044538  34.914646  100.000000  121.903247
# 3        3  0.040658  35.792263  100.000000  128.108606
# 4        4  0.045991  34.604538  100.000000  119.747400
# ..     ...       ...        ...         ...         ...
# 885    885  0.023518  40.904739  100.000000  167.319775
# 886    886  0.036148  36.916504  100.000000  136.282825
# 887    887  0.072946  30.135365    8.274126    7.514067
# 888    888  0.055459  32.790863   75.252505   80.914558
# 889    889  0.025114  40.311726  100.000000  162.503528
#
# [890 rows x 5 columns]

# %%
dd[['index', 'pred', 'opt_pred']].to_csv('sub.csv', index=False)

# %%
dd
# Out:
#      index      pred         p2    opt_pred  likely_inc
# 0        0  0.045435  34.722004  100.000000  120.561755
# 1        1  0.046221  34.556454  100.000000  119.414844
# 2        2  0.044538  34.914646  100.000000  121.903247
# 3        3  0.040658  35.792263  100.000000  128.108606
# 4        4  0.045991  34.604538  100.000000  119.747400
# ..     ...       ...        ...         ...         ...
# 885    885  0.023518  40.904739  100.000000  167.319775
# 886    886  0.036148  36.916504  100.000000  136.282825
# 887    887  0.072946  30.135365    8.274126    7.514067
# 888    888  0.055459  32.790863   75.252505   80.914558
# 889    889  0.025114  40.311726  100.000000  162.503528
#
# [890 rows x 5 columns]
